# %%
import numpy as np
import pandas as pd
# %matplotlib inline
# %config Completer.use_jedi = False

# %% [markdown]
# # Security relevance analysis
#
# In this section, we try to answer the question: `Does the fraction of security relevant keywords increase over time?`. There are two separate datasets to answer this question: the `commits` and `comments` dataset. We first load and analyze the commits dataset and then do the same with the comments dataset.

# %% [markdown]
# ### Analyze commits

# %%
# Load security relevant commits
df_commits = pd.read_csv('data/sr_commits.csv', index_col='CreationDate', parse_dates=True)

# %%
df_post_4 = df_commits[df_commits['PostId'] == 4]
df_post_4
# Out:
#                      PostId  PostVersionId  IsRelevant
# CreationDate
# 2011-10-06 18:57:46       4             28           0
# 2012-10-31 16:42:47       4             35           0
# 2013-03-14 09:35:03       4             37           0
# 2014-01-03 02:42:54       4             47           0
# 2015-10-13 10:27:48       4             51           0
# 2017-03-10 15:18:33       4             55           0
# 2017-03-10 15:18:33       4             56           0
# 2019-12-18 11:31:34       4             64           0
# 2020-02-28 11:38:30       4             65           0
# 2020-04-17 19:53:10       4             67           0
# 2020-11-11 21:19:20       4             73           0
# 2021-02-12 14:50:20       4             74           0

# %%
df_post_4.resample(rule='Y').count()[['PostId', 'PostVersionId']]
# Out:
#               PostId  PostVersionId
# CreationDate
# 2011-12-31         1              1
# 2012-12-31         1              1
# 2013-12-31         1              1
# 2014-12-31         1              1
# 2015-12-31         1              1
# 2016-12-31         0              0
# 2017-12-31         2              2
# 2018-12-31         0              0
# 2019-12-31         1              1
# 2020-12-31         3              3
# 2021-12-31         1              1

# %% [markdown]
# While the above double counted the post with Id 4, the count we are interested in is the number of security-relevant commits (not posts). In 2017, there were two security-relevant commits made to the post.
#
# So if we instead only display the count for the commits, we get:

# %%
df_post_4.resample(rule='Y').count()[['PostVersionId']]
# Out:
#               PostVersionId
# CreationDate
# 2011-12-31                1
# 2012-12-31                1
# 2013-12-31                1
# 2014-12-31                1
# 2015-12-31                1
# 2016-12-31                0
# 2017-12-31                2
# 2018-12-31                0
# 2019-12-31                1
# 2020-12-31                3
# 2021-12-31                1

# %% [markdown]
# So the count of security-relevant commits is what we are interested in
